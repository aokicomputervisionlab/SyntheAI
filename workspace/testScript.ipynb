# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
# Out:
# 2.4.0+cu118
# True
# 1

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
print(tf.__version__)
print(device_lib.list_local_devices())
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2026-02-26 13:46:04.011010: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-26 13:46:04.011043: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-26 13:46:04.012391: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.15.0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12316611210798637923
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 7134969856
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 12345032973322608462
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 2080, pci bus id: 0000:00:10.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# Num GPUs Available:  1

# %%
import jax
print(f'JAX Platform: {jax.lib.xla_bridge.get_backend().platform}')
# Out:
# JAX Platform: gpu

# %%
import cv2

# %%
# !nvidia-smi
# Out:
# Thu Feb 26 13:46:08 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.144.03             Driver Version: 550.144.03     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080        Off |   00000000:00:10.0 Off |                  N/A |
# | 27%   48C    P2             38W /  215W |     115MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+
