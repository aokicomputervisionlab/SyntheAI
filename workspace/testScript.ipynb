# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
# Out:
# 2.7.1+cu118
# True
# 1

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
print(tf.__version__)
print(device_lib.list_local_devices())
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2.15.0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5713275605929560047
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 24953618432
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 787215796213875135
# physical_device_desc: "device: 0, name: Tesla P40, pci bus id: 0000:00:10.0, compute capability: 6.1"
# xla_global_id: 416903419
# ]
# Num GPUs Available:  1

# %%
import cv2

# %%
# !nvidia-smi
# Out:
# Sun Feb 15 12:39:33 2026
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.288.01             Driver Version: 535.288.01   CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla P40                      Off | 00000000:00:10.0 Off |                  Off |
# | N/A   20C    P0              47W / 250W |    148MiB / 24576MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+
